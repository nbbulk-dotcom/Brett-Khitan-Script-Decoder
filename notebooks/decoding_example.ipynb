# %% [markdown]
# # Khitan Large Script Decoder Example
#
# Decode the Yelü Yanning inscription (1134 CE).

# %%
import sys
sys.path.append('..')
from khitan_large_decoder import KhitanDecoder

decoder = KhitanDecoder()
result = decoder.decode('yelu_yanning')
decoder.print_summary(result)
